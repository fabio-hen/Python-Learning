# %% [markdown]
# #### Bibliotecas

# %%
# pandas -> analise de dados
# getting started
# quickstart
import pandas as pd

df = pd.DataFrame(
    {
        "Name": [
            "Braund, Mr. Owen Harris",
            "Allen, Mr. William Henry",
            "Bonnell, Miss. Elizabeth",
        ],
        "Age": [22, 35, 58],
        "Sex": ["male", "male", "female"],
})

df
display(df)
print(df["Age"])
# pd.DataFrame
# pd.DataFrame -> recebe um dicionário como parâmetro e cria a tabela a partir do dicionário
# Out:
#                        Name  Age     Sex
# 0   Braund, Mr. Owen Harris   22    male
# 1  Allen, Mr. William Henry   35    male
# 2  Bonnell, Miss. Elizabeth   58  female
# 0    22
# 1    35
# 2    58
# Name: Age, dtype: int64

# %%
ages = pd.Series([22, 35, 58], name="Age")

print(df["Age"].max())
print(ages.max())
# Out:
# 58
# 58

# %%
# requests
#PyPI - Project Links na barra lateral
#Read the docs -> documentação
# Github -> ReadMe

# %% [markdown]
# #### Funções Específicas

# %%
# datas no pandas
import pandas as pd

tabela = pd.read_excel("Contratos.xlsx")
tabela['Data Pagamento'] = pd.to_datetime(tabela['Data Pagamento'], format='%d/%m/%Y')
tabela['Data Pagamento 2'] = pd.to_datetime(tabela['Data Pagamento 2'], format='%m-%d-%y')
print(tabela.dtypes)


display(tabela)
# Out:
# Cliente                     object
# Data Pagamento      datetime64[ns]
# Data Pagamento 2    datetime64[ns]
# dtype: object
#     Cliente Data Pagamento Data Pagamento 2
# 0    Fulano     2022-09-22       2022-09-22
# 1  Beltrano     2022-04-17       2022-04-17
# 2   Ciclano     2022-02-21       2022-02-21
# 3      Lira     2022-12-27       2022-12-27
# 4     Julia     2022-02-01       2022-02-01
# 5    Marcus     2022-07-08       2022-07-08
# 6    Amanda     2022-09-28       2022-09-28
# 7   Larissa     2022-05-28       2022-05-28
# 8      Alon     2022-10-06       2022-10-06

# %%
# funcao merge do pandas

emails = pd.read_excel("Emails.xlsx")
tabela = tabela.merge(emails, left_on="Cliente", right_on="Nome")
display(tabela)
# Out:
#     Cliente Data Pagamento Data Pagamento 2      Nome               Email
# 0    Fulano     2022-09-22       2022-09-22    Fulano    fulano@gmail.com
# 1  Beltrano     2022-04-17       2022-04-17  Beltrano  beltrano@gmail.com
# 2   Ciclano     2022-02-21       2022-02-21   Ciclano   ciclano@gmail.com
# 3      Lira     2022-12-27       2022-12-27      Lira      lira@gmail.com
# 4     Julia     2022-02-01       2022-02-01     Julia     julia@gmail.com
# 5    Marcus     2022-07-08       2022-07-08    Marcus    marcus@gmail.com
# 6    Amanda     2022-09-28       2022-09-28    Amanda    amanda@gmail.com
# 7   Larissa     2022-05-28       2022-05-28   Larissa   larissa@gmail.com
# 8      Alon     2022-10-06       2022-10-06      Alon      alon@gmail.com

# %%
# funcao datetime

from datetime import datetime

hoje = datetime(2022, 12, 15)
print(hoje)
# Out:
# 2022-12-15 00:00:00

# %% [markdown]
# #### APIs

# %%
# documentação de APIs cada uma é diferente da outra, 
# vejam o módulo de API que eu faço vários exemplos lá

# autenticação

# exemplo sandbox https://dadosabertos.bcb.gov.br/dataset/dinheiro-em-circulao

# exemplo documentação: https://www.alphavantage.co/

import requests

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_WEEKLY_ADJUSTED&symbol=IBM&apikey=dfsdhfsiufhsfuishfis'
r = requests.get(url)
data = r.json()

print(data)
# Out:
# {'Meta Data': {'1. Information': 'Weekly Adjusted Prices and Volumes', '2. Symbol': 'IBM', '3. Last Refreshed': '2023-03-10', '4. Time Zone': 'US/Eastern'}, 'Weekly Adjusted Time Series': {'2023-03-10': {'1. open': '129.6400', '2. high': '130.8600', '3. low': '125.1300', '4. close': '125.4500', '5. adjusted close': '125.4500', '6. volume': '20761401', '7. dividend amount': '0.0000'}, '2023-03-03': {'1. open': '131.4200', '2. high': '131.8700', '3. low': '127.7100', '4. close': '129.6400', '5. adjusted close': '129.6400', '6. volume': '17865677', '7. dividend amount': '0.0000'}, '2023-02-24': {'1. open': '134.0000', '2. high': '134.3850', '3. low': '128.8600', '4. close': '130.5700', '5. adjusted close': '130.5700', '6. volume': '14198950', '7. dividend amount': '0.0000'}, '2023-02-17': {'1. open': '136.0000', '2. high': '137.3900', '3. low': '133.8900', '4. close': '135.0200', '5. adjusted close': '135.0200', '6. volume': '16543870', '7. dividend amount': '0.0000'}, '2023-02-10': {'1. open': '135.8300', '2. high': '136.7400', '3. low': '133.3400', '4. close': '135.6000', '5. adjusted close': '135.6000', '6. volume': '22140989', '7. dividend amount': '1.6500'}, '2023-02-03': {'1. open': '134.3200', '2. high': '136.9500', '3. low': '132.8000', '4. close': '136.9400', '5. adjusted close': '135.2712', '6. volume': '27874571', '7. dividend amount': '0.0000'}, '2023-01-27': {'1. open': '141.4000', '2. high': '142.9850', '3. low': '132.9800', '4. close': '134.3900', '5. adjusted close': '132.7523', '6. volume': '43345140', '7. dividend amount': '0.0000'}, '2023-01-20': {'1. open': '146.4200', '2. high': '147.1800', '3. low': '139.7500', '4. close': '141.2000', '5. adjusted close': '139.4793', '6. volume': '21419368', '7. dividend amount': '0.0000'}, '2023-01-13': {'1. open': '144.0800', '2. high': '146.6600', '3. low': '142.9000', '4. close': '145.8900', '5. adjusted close': '144.1122', '6. volume': '14580596', '7. dividend amount': '0.0000'}, '2023-01-06': {'1. open': '141.1000', '2. high': '144.2500', '3. low': '140.0100', '4. close': '143.7000', '5. adjusted close': '141.9489', '6. volume': '13648755', '7. dividend amount': '0.0000'}, '2022-12-30': {'1. open': '141.7300', '2. high': '142.8100', '3. low': '139.4500', '4. close': '140.8900', '5. adjusted close': '139.1731', '6. volume': '10477419', '7. dividend amount': '0.0000'}, '2022-12-23': {'1. open': '140.1600', '2. high': '143.0900', '3. low': '137.1950', '4. close': '141.6500', '5. adjusted close': '139.9238', '6. volume': '19663576', '7. dividend amount': '0.0000'}, '2022-12-16': {'1. open': '147.8200', '2. high': '153.2100', '3. low': '138.9700', '4. close': '140.1600', '5. adjusted close': '138.4520', '6. volume': '33572382', '7. dividend amount': '0.0000'}, '2022-12-09': {'1. open': '147.9400', '2. high': '149.1530', '3. low': '146.2900', '4. close': '147.0500', '5. adjusted close': '145.2580', '6. volume': '15316930', '7. dividend amount': '0.0000'}, '2022-12-02': {'1. open': '147.9800', '2. high': '150.0100', '3. low': '145.6700', '4. close': '148.6700', '5. adjusted close': '146.8583', '6. volume': '20066941', '7. dividend amount': '0.0000'}, '2022-11-25': {'1. open': '147.5500', '2. high': '150.4600', '3. low': '146.4500', '4. close': '148.3700', '5. adjusted close': '146.5619', '6. volume': '16271883', '7. dividend amount': '0.0000'}, '2022-11-18': {'1. open': '142.6300', '2. high': '148.3100', '3. low': '142.0000', '4. close': '147.6400', '5. adjusted close': '145.8408', '6. volume': '22034930', '7. dividend amount': '0.0000'}, '2022-11-11': {'1. open': '136.6400', '2. high': '144.1300', '3. low': '136.5100', '4. close': '143.1700', '5. adjusted close': '141.4253', '6. volume': '25066114', '7. dividend amount': '1.6500'}, '2022-11-04': {'1. open': '138.0600', '2. high': '140.1700', '3. low': '133.9700', '4. close': '136.9600', '5. adjusted close': '133.6855', '6. volume': '22491556', '7. dividend amount': '0.0000'}, '2022-10-28': {'1. open': '130.9000', '2. high':  ...
